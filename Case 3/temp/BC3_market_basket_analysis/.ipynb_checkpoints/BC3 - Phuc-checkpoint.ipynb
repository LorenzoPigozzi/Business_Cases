# %%
# Import packages
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import matplotlib.pyplot as plt
import networkx as nx

# %%
# Import order product dataset
df = pd.read_csv('order_products.csv', usecols=['order_id', 'product_id'])
df.head()
# Out:
#    order_id  product_id
# 0        10          24
# 1        10          83
# 2        10          16
# 3        10          24
# 4        10          83

# %%
# Import product label mapping
products = pd.read_csv('products.csv')
products.head()
# Out:
#    product_id  department_id                product_name
# 0          61             19               cookies cakes
# 1         104             13           spices seasonings
# 2          94              7                         tea
# 3          38              1                frozen meals
# 4           5             13  marinades meat preparation

# %%
# Merge product labels
df = pd.merge(df, products, how='left', on='product_id').\
    drop(["product_id", "department_id"], axis=1)
df.head()
# Out:
#    order_id      product_name
# 0        10      fresh fruits
# 1        10  fresh vegetables
# 2        10       fresh herbs
# 3        10      fresh fruits
# 4        10  fresh vegetables

# %%
# Get modes and unique values
df.astype(object).describe()
# Out:
#         order_id  product_name
# count    2019501       2019501
# unique    200000           134
# top       790903  fresh fruits
# freq         137        226039

# %%
# Check product frequencies
df['product_name'].value_counts()
# Out:
# fresh fruits                  226039
# fresh vegetables              212611
# packaged vegetables fruits    109596
# yogurt                         90751
# packaged cheese                61502
#                                ...
# kitchen supplies                 561
# baby bath body care              515
# baby accessories                 504
# beauty                           387
# frozen juice                     279
# Name: product_name, Length: 134, dtype: int64

# %%
# Pivot the data - lines as orders and products as columns
pt = pd.pivot_table(df, index='order_id', columns='product_name', 
                    aggfunc=lambda x: 1 if len(x)>0 else 0).fillna(0)
pt.head()
# Out:
# product_name  air fresheners candles  asian foods  baby accessories  \
# order_id
# 10                               0.0          0.0               0.0
# 11                               0.0          0.0               0.0
# 28                               0.0          0.0               0.0
# 38                               0.0          0.0               0.0
# 56                               0.0          0.0               0.0
#
# product_name  baby bath body care  baby food formula  bakery desserts  \
# order_id
# 10                            0.0                1.0              0.0
# 11                            0.0                0.0              0.0
# 28                            0.0                0.0              0.0
# 38                            0.0                0.0              0.0
# 56                            0.0                0.0              0.0
#
# product_name  baking ingredients  baking supplies decor  beauty  \
# order_id
# 10                           0.0                    0.0     0.0
# 11                           0.0                    0.0     0.0
# 28                           0.0                    0.0     0.0
# 38                           0.0                    0.0     0.0
# 56                           0.0                    0.0     0.0
#
# product_name  beers coolers  ...  spreads  tea  tofu meat alternatives  \
# order_id                     ...
# 10                      0.0  ...      0.0  0.0                     0.0
# 11                      0.0  ...      0.0  0.0                     0.0
# 28                      0.0  ...      1.0  0.0                     0.0
# 38                      0.0  ...      0.0  0.0                     0.0
# 56                      0.0  ...      0.0  0.0                     0.0
#
# product_name  tortillas flat bread  trail mix snack mix  trash bags liners  \
# order_id
# 10                             0.0                  0.0                0.0
# 11                             0.0                  0.0                0.0
# 28                             0.0                  0.0                0.0
# 38                             0.0                  0.0                0.0
# 56                             0.0                  0.0                0.0
#
# product_name  vitamins supplements  water seltzer sparkling water  \
# order_id
# 10                             0.0                            0.0
# 11                             0.0                            0.0
# 28                             0.0                            0.0
# 38                             0.0                            0.0
# 56                             0.0                            0.0
#
# product_name  white wines  yogurt
# order_id
# 10                    0.0     0.0
# 11                    0.0     0.0
# 28                    0.0     1.0
# 38                    0.0     0.0
# 56                    0.0     0.0
#
# [5 rows x 134 columns]

# %%
# Check in how many orders was product yogurt sold
pt['yogurt'].sum()
# Out:
# 52735.0

# %%
# Apply the APRIORI algorithm to get frequent itemsets
# Rules supported in at least 5% of the transactions (more info at http://rasbt.github.io/mlxtend/user_guide/frequent_patterns/apriori/)
frequent_itemsets = apriori(pt, min_support=0.05, use_colnames=True)
frequent_itemsets.head()
# Out:
#     support              itemsets
# 0  0.076635  (baking ingredients)
# 1  0.163865               (bread)
# 2  0.067765    (breakfast bakery)
# 3  0.074330              (butter)
# 4  0.069305     (candy chocolate)

# %%
# Generate the association rules - by confidence
rulesConfidence = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.50)
rulesConfidence.sort_values(by='confidence', ascending=False, inplace=True)
rulesConfidence.head()
# Out:
#                                            antecedents         consequents  \
# 64                         (fresh fruits, fresh herbs)  (fresh vegetables)
# 125  (packaged vegetables fruits, yogurt, fresh veg...      (fresh fruits)
# 115  (milk, packaged vegetables fruits, fresh veget...      (fresh fruits)
# 34                                       (fresh herbs)  (fresh vegetables)
# 120  (packaged vegetables fruits, packaged cheese, ...      (fresh fruits)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 64             0.070135            0.444360  0.061815    0.881372  1.983463
# 125            0.087995            0.555995  0.076240    0.866413  1.558311
# 115            0.073075            0.555995  0.062535    0.855765  1.539159
# 34             0.093005            0.444360  0.078655    0.845707  1.903203
# 120            0.081970            0.555995  0.068325    0.833537  1.499180
#
#      leverage  conviction
# 64   0.030650    4.683872
# 125  0.027315    3.323711
# 115  0.021906    3.078336
# 34   0.037327    3.601205
# 120  0.022750    2.667284

# %%
# Generate the association rules - by lift
rulesLift = association_rules(frequent_itemsets, metric="lift", min_threshold=1.5)
rulesLift.sort_values(by='lift', ascending=False, inplace=True)
rulesLift.head()
# Out:
#                                     antecedents  \
# 30                                (fresh herbs)
# 29             (fresh fruits, fresh vegetables)
# 31                           (fresh vegetables)
# 28                  (fresh fruits, fresh herbs)
# 128  (fresh fruits, packaged vegetables fruits)
#
#                           consequents  antecedent support  consequent support  \
# 30   (fresh fruits, fresh vegetables)            0.093005            0.317560
# 29                      (fresh herbs)            0.317560            0.093005
# 31        (fresh fruits, fresh herbs)            0.444360            0.070135
# 28                 (fresh vegetables)            0.070135            0.444360
# 128        (yogurt, fresh vegetables)            0.269870            0.144660
#
#       support  confidence      lift  leverage  conviction
# 30   0.061815    0.664642  2.092964  0.032280    2.034958
# 29   0.061815    0.194656  2.092964  0.032280    1.126221
# 31   0.061815    0.139110  1.983463  0.030650    1.080121
# 28   0.061815    0.881372  1.983463  0.030650    4.683872
# 128  0.076240    0.282506  1.952899  0.037201    1.192122

# %% [markdown]
# #### Rules are of type `frozenset`, which is a Python built-in type that behaves similarly to sets except that it is immutable. Frozensets have functions to check if there are subsets, supersets, etc. More info at https://www.journaldev.com/22850/python-frozenset
#
#
# ### EXPLORE FREQUENT_ITEMSETS

# %%
# Add a column with the length
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))

# Length=2 and Support>=0.2
frequent_itemsets[(frequent_itemsets['length'] == 2) & (frequent_itemsets['support'] >= 0.2)]
# Out:
#       support                                        itemsets  length
# 75   0.317560                (fresh fruits, fresh vegetables)       2
# 85   0.269870      (fresh fruits, packaged vegetables fruits)       2
# 100  0.234555  (packaged vegetables fruits, fresh vegetables)       2

# %%
# fresh fruits and yogurt
frequent_itemsets[ frequent_itemsets['itemsets'] == {'yogurt', 'fresh fruits'}]
# Out:
#      support                itemsets  length
# 91  0.188225  (fresh fruits, yogurt)       2

# %%
# packaged cheese
frequent_itemsets[ frequent_itemsets['itemsets'] == {'packaged cheese'}]
# Out:
#      support           itemsets  length
# 34  0.230995  (packaged cheese)       1

# %%
# High Confidence and high Lift - complementary products
rulesConfidence[(rulesConfidence['confidence'] >= 0.8) & (rulesConfidence['lift'] >= 1.8)]
# Out:
#                     antecedents         consequents  antecedent support  \
# 64  (fresh fruits, fresh herbs)  (fresh vegetables)            0.070135
# 34                (fresh herbs)  (fresh vegetables)            0.093005
#
#     consequent support   support  confidence      lift  leverage  conviction
# 64             0.44436  0.061815    0.881372  1.983463  0.030650    4.683872
# 34             0.44436  0.078655    0.845707  1.903203  0.037327    3.601205

# %%
# High Confidence rules where "fresh vegetables" and "fresh fruits" are in the LHS
rulesConfidence[rulesConfidence['antecedents']=={'fresh vegetables', 'fresh fruits'}]  # Because rules are a "frozenset" object, the order of items is not important
# Out:
#                          antecedents                   consequents  \
# 75  (fresh fruits, fresh vegetables)  (packaged vegetables fruits)
#
#     antecedent support  consequent support  support  confidence      lift  \
# 75             0.31756            0.365415  0.18658    0.587543  1.607877
#
#     leverage  conviction
# 75  0.070539    1.538546

# %%
# High Confidence rules where "packaged vegetables fruits" is in the RHS
rulesConfidence[['packaged vegetables fruits' in elem for elem in rulesConfidence['consequents']]]
# Out:
#                                            antecedents  \
# 119  (fresh fruits, packaged cheese, fresh vegetables)
# 124           (fresh fruits, yogurt, fresh vegetables)
# 113             (fresh fruits, milk, fresh vegetables)
# 108                (soy lactosefree, fresh vegetables)
# 86                      (fresh fruits, frozen produce)
# 110                         (yogurt, fresh vegetables)
# 105                (packaged cheese, fresh vegetables)
# 63                            (eggs, fresh vegetables)
# 52                           (bread, fresh vegetables)
# 75                    (fresh fruits, fresh vegetables)
# 112                          (packaged cheese, yogurt)
# 101                           (milk, fresh vegetables)
# 92                     (fresh fruits, packaged cheese)
# 60                                (fresh fruits, eggs)
# 95                     (fresh fruits, soy lactosefree)
# 35                                       (fresh herbs)
# 99                              (fresh fruits, yogurt)
# 50                               (fresh fruits, bread)
# 14                              (fresh dips tapenades)
# 46                                    (frozen produce)
# 56                      (fresh fruits, chips pretzels)
# 111                                     (yogurt, milk)
# 89                                (fresh fruits, milk)
# 42                                  (fresh vegetables)
# 127                         (yogurt, fresh vegetables)
# 47                                        (lunch meat)
# 97       (fresh fruits, water seltzer sparkling water)
# 10                                              (eggs)
# 122                (packaged cheese, fresh vegetables)
# 116                           (milk, fresh vegetables)
#
#                                     consequents  antecedent support  \
# 119                (packaged vegetables fruits)            0.104570
# 124                (packaged vegetables fruits)            0.118420
# 113                (packaged vegetables fruits)            0.099590
# 108                (packaged vegetables fruits)            0.094120
# 86                 (packaged vegetables fruits)            0.089235
# 110                (packaged vegetables fruits)            0.144660
# 105                (packaged vegetables fruits)            0.135850
# 63                 (packaged vegetables fruits)            0.084310
# 52                 (packaged vegetables fruits)            0.091590
# 75                 (packaged vegetables fruits)            0.317560
# 112                (packaged vegetables fruits)            0.088520
# 101                (packaged vegetables fruits)            0.124715
# 92                 (packaged vegetables fruits)            0.155900
# 60                 (packaged vegetables fruits)            0.095325
# 95                 (packaged vegetables fruits)            0.117480
# 35                 (packaged vegetables fruits)            0.093005
# 99                 (packaged vegetables fruits)            0.188225
# 50                 (packaged vegetables fruits)            0.112410
# 14                 (packaged vegetables fruits)            0.098205
# 46                 (packaged vegetables fruits)            0.122580
# 56                 (packaged vegetables fruits)            0.106300
# 111                (packaged vegetables fruits)            0.095705
# 89                 (packaged vegetables fruits)            0.164310
# 42                 (packaged vegetables fruits)            0.444360
# 127  (fresh fruits, packaged vegetables fruits)            0.144660
# 47                 (packaged vegetables fruits)            0.103890
# 97                 (packaged vegetables fruits)            0.111045
# 10                 (packaged vegetables fruits)            0.136490
# 122  (fresh fruits, packaged vegetables fruits)            0.135850
# 116  (fresh fruits, packaged vegetables fruits)            0.124715
#
#      consequent support   support  confidence      lift  leverage  conviction
# 119            0.365415  0.068325    0.653390  1.788077  0.030114    1.830833
# 124            0.365415  0.076240    0.643810  1.761860  0.032968    1.781592
#      leverage  conviction
# 110 -0.002409    0.978033
# 111 -0.002409    0.993328
# 231  0.001944    1.007645
# 234  0.001944    1.014983
# 82   0.003735    1.008395
# 83   0.003735    1.045573
# 133  0.003188    1.010929
# 132  0.003188    1.026725
# 59   0.003042    1.066094
# 58   0.003042    1.006189

# %%
### Plot a basic network graph of the top 50 confidence rules
# Create a copy of the rules and transform the frozensets to strings
rulesToPlot = rulesConfidence.copy(deep=True)
rulesToPlot['LHS'] = [','.join(list(x)) for x in rulesToPlot['antecedents']]
rulesToPlot['RHS'] = [','.join(list(x)) for x in rulesToPlot['consequents']]
# Remove duplicate if reversed rules
rulesToPlot['sortedRow'] = [sorted([a,b]) for a,b in zip(rulesToPlot.LHS, rulesToPlot.RHS)]
rulesToPlot['sortedRow'] = rulesToPlot['sortedRow'].astype(str)
rulesToPlot.drop_duplicates(subset=['sortedRow'], inplace=True)
# Plot
rulesToPlot=rulesToPlot[:50]
fig = plt.figure(figsize=(20, 20)) 
G = nx.from_pandas_edgelist(rulesToPlot, 'LHS', 'RHS')  
# Each node is an itemset (either source or target) and the edges connect the itemsets if they consist of a high confidence rule
nx.draw(G, with_labels=True, node_size=30, node_color="red", pos=nx.spring_layout(G))
plt.axis('equal')
plt.show()
#fig.savefig('figure.svg')
# TRY TO PLOT THE DIRECTION OF SOURCE -> TARGET

# %% [markdown]
# # Orders analysis

# %%
order_df = pd.read_csv('orders.csv')

# %%
order_df
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0        2425083    49125             1          2                 18
# 1        1944304   162867             1          3                 17
# 2        1201011   147243            14          0                 16
# 3        1906860   195275            81          1                 11
# 4        2766469    58222             3          6                 11
# ...          ...      ...           ...        ...                ...
# 199995   2768632   137024            14          3                  8
# 199996   1754449   190356             9          6                 15
# 199997    792803    84264             5          3                 13
# 199998   3390742   199430            16          3                 18
# 199999    458285   128787            42          2                 19
#
#         days_since_prior_order
# 0                          NaN
# 1                          NaN
# 2                          3.0
# 3                          3.0
# 4                          6.0
# ...                        ...
# 199995                     8.0
# 199996                     3.0
# 199997                    21.0
# 199998                     5.0
# 199999                     3.0
#
# [200000 rows x 6 columns]

# %%
# show figure:
plt.figure(figsize=(8, 6))
# Draw a nested violinplot and split the violins for easier comparison
sns.countplot(x = 'order_dow', data = order_df,
              palette=[sns.color_palette('icefire')[i] for i in range(0,6)])
              #order = pd.value_counts(data['LeadTime']).iloc[:10].index)
sns.despine(left=True)
plt.title("Order Day of week", fontsize=20)
plt.xlabel("DOW", fontsize=16)
plt.xticks(rotation=45)
plt.ylabel("Number of orders", fontsize=16)
plt.show()

# %%
# show figure:
plt.figure(figsize=(8, 6))
# Draw a nested violinplot and split the violins for easier comparison
sns.countplot(x = 'order_hour_of_day', data = order_df,
              palette='icefire')
              #order = pd.value_counts(data['LeadTime']).iloc[:10].index)
sns.despine(left=True)
plt.title("Order Day of week", fontsize=20)
plt.xlabel("DOW", fontsize=16)
plt.xticks(rotation=45)
plt.ylabel("Number of orders", fontsize=16)
plt.show()

# %%
# show figure:
plt.figure(figsize=(8, 6))
# Draw a nested violinplot and split the violins for easier comparison
sns.countplot(x = 'days_since_prior_order', data = order_df,
              palette='icefire')
              #order = pd.value_counts(data['LeadTime']).iloc[:10].index)
sns.despine(left=True)
plt.title("Order Day of week", fontsize=20)
plt.xlabel("DOW", fontsize=16)
plt.xticks(rotation=45)
plt.ylabel("Number of orders", fontsize=16)
plt.show()
