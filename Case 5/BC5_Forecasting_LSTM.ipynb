# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math
# Sklearn
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler, PowerTransformer,QuantileTransformer, OneHotEncoder
from sklearn.metrics import mean_squared_error
# Keras
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.layers import Bidirectional, GRU
from keras.models import Sequential
from keras.regularizers import l2
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
#Visualization
import matplotlib.cm as cm
from sklearn import random_projection

import datetime

# %%
dtype_dict = {
    'ProductFamily_ID':'category',
    'ProductCategory_ID':'category',
    'ProductBrand_ID':'category',
    'ProductName_ID':'category',
    'ProductPackSKU_ID':'category',
    'Point-of-Sale_ID':'category',
    'Measures':'category',
    'Quantity':'float32',
    'Total_Sales':'float32',
    'Value':'float32',
    'Week': 'int32',
    'Year':'int32'
}
original_path = r'D:\NOVAIMS_MAA\NOVAIMS_MAA_2020e21_BusinessCasesDataScience_MindOverData_RetailChallenge.csv'
processed_path = r'D:\NOVAIMS_MAA\NOVAIMS_MAA_final_1.csv'
timeseries_path = r'D:\NOVAIMS_MAA\timeseries\product_total_ts.csv'

# %%
example = pd.read_csv(processed_path,dtype=dtype_dict,parse_dates=['Date'],nrows = 100,usecols = [1,2,3,4,5,6,7,8,9])
example.head()
# Out:
#   ProductFamily_ID ProductCategory_ID ProductBrand_ID ProductName_ID  \
# 0               16                 11             306            649
# 1               16                 11             306            649
# 2               16                 11             306            649
# 3               16                 11             306            649
# 4               16                 11             306            649
#
#   ProductPackSKU_ID Point-of-Sale_ID       Date  Quantity  Total_Sales
# 0              1970                1 2017-03-04       2.0       1540.0
# 1              1970                1 2016-05-02       4.0       3080.0
# 2              1970                1 2016-10-24       2.0       1540.0
# 3              1970                1 2017-10-13       2.0       1620.0
# 4              1970                1 2017-10-14       2.0       1620.0

# %%
df = pd.read_csv(timeseries_path,dtype=dtype_dict,usecols = [1,2,3,4,5])

# %%
df.head()
# Out:
#    Year  Month  Week ProductName_ID  Quantity
# 0  2016      1     1           1000     766.0
# 1  2016      1     1           1004     727.0
# 2  2016      1     1           1006     491.0
# 3  2016      1     1           1007     636.0
# 4  2016      1     1           1013    1641.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7174080 entries, 0 to 7174079
# Data columns (total 5 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   Year            int32
#  1   Month           int64
#  2   Week            int32
#  3   ProductName_ID  category
#  4   Quantity        float32
# dtypes: category(1), float32(1), int32(2), int64(1)
# memory usage: 150.6 MB

# %%
def preprocessing(dataframe,product_id, period = "Month"):
    if period == "Month":
        data = dataframe[dataframe['ProductName_ID'] == product_id]
        data = data.groupby(['Year','Month']).sum()['Quantity'].reset_index()
        data['Month'] =  data['Month'].astype('string').apply(lambda x: x if int(x) >=10 else "0"+x)
        data['TimeSeries'] = data['Year'].astype('string') + data['Month']
        #drop non-relevant columns
        data.drop(['Year','Month'], axis=1, inplace=True)
        data.set_index('TimeSeries',inplace=True)
        data.sort_index(inplace=True)
        print("monthly timeseries generated")
        return data
    elif period == "Week":
        data = dataframe[dataframe['ProductName_ID'] == product_id]
        data = data.groupby(['Year','Week']).sum()['Quantity'].reset_index()      
        data['Week'] =  data['Week'].astype('string').apply(lambda x: x if int(x) >=10 else "0"+x)
        data = data[data['Week'] != "53"]
        data['TimeSeries'] = data['Year'].astype('string') + data['Week']
        #drop non-relevant columns
        data.drop(['Year','Week'], axis=1, inplace=True)
        data.set_index('TimeSeries',inplace=True)
        data.dropna(inplace=True)
        data.sort_index(inplace=True)
        print("weekly timeseries generated")
        return data
    else:
        print("Error, chosen period not available")   

def line_plot2(line1, line2,label1=None, label2=None, title='', lw=2):
    fig, ax = plt.subplots(1, figsize=(13, 7))
    ax.plot(line1, label=label1, linewidth=lw)
    ax.plot(line2, label=label2, linewidth=lw)
    ax.set_ylabel('price [USD]', fontsize=14)
    ax.set_xticklabels(ax.get_xticks(), rotation = 45)
    ax.set_title(title, fontsize=16)
    ax.legend(loc='best', fontsize=16)

# create a differenced series
def difference(dataset, interval=1):
    diff = list()
    dataset_val = dataset.values
    for i in range(interval, len(dataset)):
        value = dataset_val[i] - dataset_val[i - interval]
        diff.append(value[0])
    return pd.DataFrame({'diff':diff},index = dataset[1:].index)

def scale_func(df,size_split):
    len_df = df.shape[0]
    scaler = MinMaxScaler()
    scaler.fit(df.iloc[:int(len_df*size_split),:])
    scaled_data = scaler.transform(df)
    scaled_data = pd.DataFrame(scaled_data,index=df.index, columns=df.columns)
    return scaled_data, scaler
def reshape_input(X,Y):
    X, Y = np.array(X), np.array(Y)
    Y = Y.reshape(Y.shape[0], Y.shape[1])
    X = np.reshape(X, (X.shape[0], X.shape[1], 1))
    return X,Y
#create the training data set
def generate_input(df, window, out,size_split = 0.8):
    # df is the differencing dataframe
    #create the scaled training data set
    scaled_data, scaler = scale_func(df,size_split=size_split)
    #Split the data into x_train and y_train data sets
    len_df = scaled_data.shape[0]
    x_train,y_train = [],[]
    x_val,y_val = [],[]
    train_size = int(len_df*size_split)
    for i in range(window, train_size-out+1):
        x_train.append(scaled_data.iloc[i-window:i,:])
        y_train.append(scaled_data.iloc[i:(i+out),:])
    x_train,y_train = reshape_input(x_train,y_train)
    for i in range(train_size, len_df-out+1):
        x_val.append(scaled_data.iloc[i-window:i,:])
        y_val.append(scaled_data.iloc[i:(i+out),:])
    x_val,y_val = reshape_input(x_val,y_val)
    #y_train = np.reshape(y_train, (y_train.shape[0], y_train.shape[1]))
    return x_train, y_train, x_val,y_val, scaled_data,scaler

def model_base_build(input_shape,output_len):
    #build the lstm model
    model = Sequential()
    model.add(LSTM(100, return_sequences=False,  input_shape = input_shape))
    #model.add(LSTM(10, return_sequences=False, dropout=0.1, recurrent_dropout=0.1))
    model.add(Dense(output_len))
    model.add(Activation('linear'))
    #compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

def plot_loss_histories(histories,names):
    rows = math.ceil(len(histories)/2)
    fig, axes = plt.subplots(rows,2, constrained_layout=False, figsize=(16,5*rows))
    fig.suptitle("Training loss vs Validation Loss\n", fontsize=25)
    # Draw nested boxplots
    for history, name, ax in zip(histories, names , axes.flatten()):
        ax.plot(history.history['loss'])
        ax.plot(history.history['val_loss'])
        ax.set_title("{} model".format(name), fontsize=13)
        ax.set_xlabel('epoch')
        ax.set_ylabel('loss')
        ax.legend(['train', 'validation'], loc='upper right')
    fig.subplots_adjust(hspace=0.3)
    plt.show()

# invert differenced forecast
def inverse_difference(last_ob, forecast):
	# invert first forecast
    inverted = list()
    inverted.append(forecast[0] + last_ob)
	# propagate difference forecast using inverted first value
    for i in range(1, len(forecast)):
        inverted.append(forecast[i] + inverted[i-1])
    return inverted
# inverse data transform on forecasts
def inverse_transform(data, forecasts, scaler, x_val):
    inverted = list()
    out_put_len = forecasts.shape[1]
    for i in range(len(forecasts)): 
        forecast = np.array(forecasts[i])
        forecast = forecast.reshape(1, len(forecast))
        # invert scaling
        inv_scale = scaler.inverse_transform(forecast)
        inv_scale = inv_scale[0, :]
        # invert differencing
        index = len(data) - len(x_val) + i - out_put_len
        last_ob = data.values[index]
        inv_diff = inverse_difference(last_ob, inv_scale)
        inverted.append(inv_diff)
    return inverted

def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true))
# evaluate the RMSE for each forecast time step

def evaluate_forecasts(test, forecasts, n_lag, n_seq):
    for i in range(n_seq):
        actual = [row[i] for row in test]
        predicted = [forecast[i] for forecast in forecasts]
        rmse = math.sqrt(mean_squared_error(actual,predicted))
        mape = mean_absolute_percentage_error(actual,predicted)
        print('t+%d RMSE: %f' % ((i+1), rmse))
        print('t+%d MAPE: %0.4f' % ((i+1), mape))

def plot_series(data,figsize=(12,6)):
    plt.figure(figsize=figsize)
    plt.title('Quantity Timeseries')
    plt.xticks(rotation=45)
    plt.plot(data)      

# plot the forecasts in the context of the original dataset
def plot_forecasts(series,train_df, val_df, forecasts, out):
    plt.figure(figsize=(16,8))
    # plot the entire dataset in blue
    plt.plot(data.loc[train_df.index], label = "Train")
    plt.plot(data.loc[val_df.index], label = "Validation")
    if out == 1:
        lines = pd.Series()
        for i in range(len(forecasts)):
            off_s = len(series) - len(val_df) + i - 1
            off_e = off_s + len(forecasts[i])
            xaxis = [x for x in range(off_s, off_e)]
            yaxis = forecasts[i]
            lines = lines.append(pd.Series(yaxis[0],index = xaxis))
        plt.plot(lines.index, lines.values, color='red')
    # show the plot
        plt.xticks(rotation = 90)
        left, right = plt.xlim()
        plt.xlim(left = (left+right)/2,right=right)
        plt.show()
        return lines
    # plot the forecasts in red
    else:
        for i in range(len(forecasts)):
            off_s = len(series) - len(val_df) + i - 1
            off_e = off_s + len(forecasts[i])
            xaxis = [x for x in range(off_s, off_e)]
            yaxis = forecasts[i]
            plt.plot(xaxis, yaxis, color='red')
        # show the plot
        plt.xticks(rotation = 90)
        left, right = plt.xlim()
        plt.xlim(left = (left+right)/2,right=right)
        plt.show()

# %%
# Check for top 10 products
df.groupby('ProductName_ID').sum()['Quantity'].sort_values(ascending = False)[:10]
# Out:
# ProductName_ID
# 1277    3170543.0
# 2609    3070767.0
# 481     2983412.0
# 993     2837871.0
# 1147    2801077.0
# 1234    2528432.0
# 2802    2521720.0
# 847     2447311.0
# 226     2437948.0
# 1422    2414555.0
# Name: Quantity, dtype: float32

# %%
data = preprocessing(df,product_id='2609')
data.drop(index = ["201911","201912"],inplace = True)
plot_series(data)
# Out:
# monthly timeseries generated

# %%
plot_acf(data)
plt.show()

# %%
plot_pacf(data, lags=10)
plt.show()

# %%
dataset = difference(data)
n = dataset.shape[0]
train_df = dataset[0:int(n*.8)]
val_df = dataset[int(n*0.8):]
line_plot2(line1 = train_df, line2 = val_df, label1='training',label2='val',title='')

# %%
x_train, y_train, x_val, y_val, scaled_df, scaler = generate_input(dataset,window = 6, out = 3)
print(scaled_df.shape)
print(x_train.shape)
print(y_train.shape)
print(x_val.shape)
print(y_val.shape)

# %%
LSTM1 = model_base_build(input_shape= (x_train.shape[1],x_train.shape[2]),output_len=y_train.shape[1])
history1 = LSTM1.fit(x_train, y_train, batch_size=1, epochs=180   ,validation_data=(x_val,y_val))
# Out:
# Epoch 1/180
# 28/28 [==============================] - 3s 33ms/step - loss: 0.2272 - val_loss: 0.1546
# Epoch 2/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0694 - val_loss: 0.1481
# Epoch 3/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0606 - val_loss: 0.1475
# Epoch 4/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0568 - val_loss: 0.1475
# Epoch 5/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0501 - val_loss: 0.1486
# Epoch 6/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0471 - val_loss: 0.1461
# Epoch 7/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0728 - val_loss: 0.1449
# Epoch 8/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0889 - val_loss: 0.1421
# Epoch 9/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0534 - val_loss: 0.1413
# Epoch 10/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0455 - val_loss: 0.1422
# Epoch 11/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0546 - val_loss: 0.1377
# Epoch 12/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0504 - val_loss: 0.1372
# Epoch 13/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0363 - val_loss: 0.1343
# Epoch 14/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0526 - val_loss: 0.1315
# Epoch 15/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0447 - val_loss: 0.1271
# Epoch 16/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0481 - val_loss: 0.1249
# Epoch 17/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0600 - val_loss: 0.1199
# Epoch 18/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0528 - val_loss: 0.1161
# Epoch 19/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0408 - val_loss: 0.1112
# Epoch 20/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0508 - val_loss: 0.1146
# Epoch 21/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0498 - val_loss: 0.1092
# Epoch 22/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0425 - val_loss: 0.1092
# Epoch 23/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0464 - val_loss: 0.1076
# Epoch 24/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0399 - val_loss: 0.1105
# Epoch 25/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0483 - val_loss: 0.1076
# Epoch 26/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0672 - val_loss: 0.1070
# Epoch 27/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0422 - val_loss: 0.1070
# Epoch 28/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0611 - val_loss: 0.1071
# Epoch 29/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0506 - val_loss: 0.1074
# Epoch 30/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0505 - val_loss: 0.1067
# Epoch 31/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0458 - val_loss: 0.1072
# Epoch 32/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0459 - val_loss: 0.1061
# Epoch 33/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0475 - val_loss: 0.1049
# Epoch 34/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0423 - val_loss: 0.1052
# Epoch 35/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0401 - val_loss: 0.1096
# Epoch 36/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0380 - val_loss: 0.1049
# Epoch 37/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0385 - val_loss: 0.1062
# Epoch 38/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0552 - val_loss: 0.1075
# Epoch 39/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0445 - val_loss: 0.1049
# Epoch 40/180
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0605 - val_loss: 0.1065
# Epoch 41/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0355 - val_loss: 0.1045
# Epoch 42/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0379 - val_loss: 0.1043
# Epoch 43/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0584 - val_loss: 0.1105
# Epoch 44/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0364 - val_loss: 0.1064
# Epoch 45/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0574 - val_loss: 0.1079
# Epoch 46/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0402 - val_loss: 0.1037
# Epoch 47/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0450 - val_loss: 0.1059
# Epoch 48/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0477 - val_loss: 0.1071
# Epoch 49/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0367 - val_loss: 0.1038
# Epoch 50/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0606 - val_loss: 0.1038
# Epoch 51/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0532 - val_loss: 0.1052
# Epoch 52/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0468 - val_loss: 0.1007
# Epoch 53/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0356 - val_loss: 0.1078
# Epoch 54/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0487 - val_loss: 0.1067
# Epoch 55/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0462 - val_loss: 0.1021
# Epoch 56/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0459 - val_loss: 0.1019
# Epoch 57/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0512 - val_loss: 0.1029
# Epoch 58/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0411 - val_loss: 0.1041
# Epoch 59/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0471 - val_loss: 0.1009
# Epoch 60/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0349 - val_loss: 0.0993
# Epoch 61/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0513 - val_loss: 0.0987
# Epoch 62/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0506 - val_loss: 0.0987
# Epoch 63/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0339 - val_loss: 0.1004
# Epoch 64/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0375 - val_loss: 0.0983
# Epoch 65/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0407 - val_loss: 0.0988
# Epoch 66/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0439 - val_loss: 0.0974
# Epoch 67/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0339 - val_loss: 0.0985
# Epoch 68/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0423 - val_loss: 0.0988
# Epoch 69/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0416 - val_loss: 0.0984
# Epoch 70/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0460 - val_loss: 0.1001
# Epoch 71/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0374 - val_loss: 0.1019
# Epoch 72/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0319 - val_loss: 0.0972
# Epoch 73/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0524 - val_loss: 0.0970
# Epoch 74/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0346 - val_loss: 0.0965
# Epoch 75/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0525 - val_loss: 0.0954
# Epoch 76/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0449 - val_loss: 0.0966
# Epoch 77/180
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0456 - val_loss: 0.0955
# Epoch 78/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0429 - val_loss: 0.0954
# Epoch 79/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0323 - val_loss: 0.0990
# Epoch 80/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0370 - val_loss: 0.0968
# Epoch 81/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0464 - val_loss: 0.1003
# Epoch 82/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0558 - val_loss: 0.0956
# Epoch 83/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0406 - val_loss: 0.0986
# Epoch 84/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0450 - val_loss: 0.0965
# Epoch 85/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0573 - val_loss: 0.0946
# Epoch 86/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0330 - val_loss: 0.0965
# Epoch 87/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0391 - val_loss: 0.0963
# Epoch 88/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0328 - val_loss: 0.0932
# Epoch 89/180
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0421 - val_loss: 0.0971
# Epoch 90/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0314 - val_loss: 0.0928
# Epoch 91/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0366 - val_loss: 0.0933
# Epoch 92/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0418 - val_loss: 0.0937
# Epoch 93/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0374 - val_loss: 0.0952
# Epoch 94/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0534 - val_loss: 0.0929
# Epoch 95/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0415 - val_loss: 0.0969
# Epoch 96/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0404 - val_loss: 0.0938
# Epoch 97/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0283 - val_loss: 0.0962
# Epoch 98/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0364 - val_loss: 0.0944
# Epoch 99/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0401 - val_loss: 0.0959
# Epoch 100/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0268 - val_loss: 0.0954
# Epoch 101/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0298 - val_loss: 0.0957
# Epoch 102/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0425 - val_loss: 0.1001
# Epoch 103/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0259 - val_loss: 0.1018
# Epoch 104/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0214 - val_loss: 0.1011
# Epoch 105/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0308 - val_loss: 0.1033
# Epoch 106/180
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0234 - val_loss: 0.1105
# Epoch 107/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0263 - val_loss: 0.1122
# Epoch 108/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0391 - val_loss: 0.1078
# Epoch 109/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0229 - val_loss: 0.1078
# Epoch 110/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0263 - val_loss: 0.1098
# Epoch 111/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0263 - val_loss: 0.1142
# Epoch 112/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0255 - val_loss: 0.1140
# Epoch 113/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0234 - val_loss: 0.1106
# Epoch 114/180
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0193 - val_loss: 0.1094
# Epoch 115/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0148 - val_loss: 0.1031
# Epoch 116/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0222 - val_loss: 0.1091
# Epoch 117/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0125 - val_loss: 0.1105
# Epoch 118/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0150 - val_loss: 0.1142
# Epoch 119/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0159 - val_loss: 0.1115
# Epoch 120/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0180 - val_loss: 0.1127
# Epoch 121/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0133 - val_loss: 0.1159
# Epoch 122/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0202 - val_loss: 0.1104
# Epoch 123/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0190 - val_loss: 0.1188
# Epoch 124/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0198 - val_loss: 0.1160
# Epoch 125/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0145 - val_loss: 0.1184
# Epoch 126/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0174 - val_loss: 0.1115
# Epoch 127/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0117 - val_loss: 0.1151
# Epoch 128/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0148 - val_loss: 0.1092
# Epoch 129/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0124 - val_loss: 0.1160
# Epoch 130/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0162 - val_loss: 0.1105
# Epoch 131/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0138 - val_loss: 0.1079
# Epoch 132/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0141 - val_loss: 0.1119
# Epoch 133/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0136 - val_loss: 0.1155
# Epoch 134/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0192 - val_loss: 0.1191
# Epoch 135/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0129 - val_loss: 0.1166
# Epoch 136/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0148 - val_loss: 0.1105
# Epoch 137/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0139 - val_loss: 0.1111
# Epoch 138/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0163 - val_loss: 0.1151
# Epoch 139/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0136 - val_loss: 0.1109
# Epoch 140/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0138 - val_loss: 0.1126
# Epoch 141/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0162 - val_loss: 0.1165
# Epoch 142/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0173 - val_loss: 0.1139
# Epoch 143/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0145 - val_loss: 0.1141
# Epoch 144/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0120 - val_loss: 0.1149
# Epoch 145/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0108 - val_loss: 0.1111
# Epoch 146/180
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0121 - val_loss: 0.1151
# Epoch 147/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0097 - val_loss: 0.1132
# Epoch 148/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0129 - val_loss: 0.1125
# Epoch 149/180
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0139 - val_loss: 0.1137
# Epoch 150/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0129 - val_loss: 0.1103
# Epoch 151/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0144 - val_loss: 0.1113
# Epoch 152/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0166 - val_loss: 0.1100
# Epoch 153/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0088 - val_loss: 0.1091
# Epoch 154/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0103 - val_loss: 0.1119
# Epoch 155/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0104 - val_loss: 0.1082
# Epoch 156/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0130 - val_loss: 0.1127
# Epoch 157/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0129 - val_loss: 0.1150
# Epoch 158/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0104 - val_loss: 0.1107
# Epoch 159/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0126 - val_loss: 0.1088
# Epoch 160/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0130 - val_loss: 0.1137
# Epoch 161/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0107 - val_loss: 0.1093
# Epoch 162/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0083 - val_loss: 0.1108
# Epoch 163/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0121 - val_loss: 0.1032
# Epoch 164/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0145 - val_loss: 0.1043
# Epoch 165/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0095 - val_loss: 0.1071
# Epoch 166/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0061 - val_loss: 0.1041
# Epoch 167/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0091 - val_loss: 0.1085
# Epoch 168/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0112 - val_loss: 0.1138
# Epoch 169/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0146 - val_loss: 0.1136
# Epoch 170/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0149 - val_loss: 0.1056
# Epoch 171/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0100 - val_loss: 0.1100
# Epoch 172/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0146 - val_loss: 0.1082
# Epoch 173/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0114 - val_loss: 0.1030
# Epoch 174/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0112 - val_loss: 0.1110
# Epoch 175/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0102 - val_loss: 0.1092
# Epoch 176/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0114 - val_loss: 0.1055
# Epoch 177/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0068 - val_loss: 0.1127
# Epoch 178/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0133 - val_loss: 0.1035
# Epoch 179/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0094 - val_loss: 0.1085
# Epoch 180/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0153 - val_loss: 0.1109

# %%
histories = [history1]
names = ['LSTM1']
plot_loss_histories(histories,names)

# %%
forecasts = LSTM1.predict(x_val)
# inverse transform
y_val_original = inverse_transform(data,y_val,scaler,x_val)
y_predicted = inverse_transform(data,forecasts,scaler,x_val)
evaluate_forecasts(y_val_original, y_predicted, 6, 3)
# Out:
# t+1 RMSE: 4565.489459
# t+1 MAPE: 0.0432
# t+2 RMSE: 4607.789492
# t+2 MAPE: 0.0480
# t+3 RMSE: 4997.176603
# t+3 MAPE: 0.0573

# %%
plot_forecasts(data,train_df,val_df,y_predicted,3)

# %% [markdown]
# ## Seasonal product

# %%
data = preprocessing(df,product_id='481')
data.drop(index = ["201911","201912"],inplace = True)
plot_series(data)
# Out:
# monthly timeseries generated

# %%
plot_acf(data)
plt.show()

# %%
plot_pacf(data, lags=10)
plt.show()

# %%
dataset = difference(data)
n = dataset.shape[0]
train_df = dataset[0:int(n*.8)]
val_df = dataset[int(n*0.8):]
line_plot2(line1 = train_df, line2 = val_df, label1='training',label2='val',title='')

# %%
x_train, y_train, x_val, y_val, scaled_df, scaler = generate_input(dataset,window = 6, out = 3)
print(scaled_df.shape)
print(x_train.shape)
print(y_train.shape)
print(x_val.shape)
print(y_val.shape)
# Out:
# (45, 1)
# (28, 6, 1)
# (28, 3)
# (7, 6, 1)
# (7, 3)

# %%
LSTM1 = model_base_build(input_shape= (x_train.shape[1],x_train.shape[2]),output_len=y_train.shape[1])
history1 = LSTM1.fit(x_train, y_train, batch_size=1, epochs=180   ,validation_data=(x_val,y_val))
# Out:
# Epoch 1/180
# 28/28 [==============================] - 17s 36ms/step - loss: 0.1528 - val_loss: 0.0620
# Epoch 2/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0507 - val_loss: 0.0283
# Epoch 3/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0747 - val_loss: 0.0259
# Epoch 4/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0526 - val_loss: 0.0339
# Epoch 5/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0466 - val_loss: 0.0254
# Epoch 6/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0469 - val_loss: 0.0235
# Epoch 7/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0545 - val_loss: 0.0253
# Epoch 8/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0628 - val_loss: 0.0212
# Epoch 9/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0465 - val_loss: 0.0193
# Epoch 10/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0427 - val_loss: 0.0169
# Epoch 11/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0371 - val_loss: 0.0139
# Epoch 12/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0527 - val_loss: 0.0247
# Epoch 13/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0406 - val_loss: 0.0157
# Epoch 14/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0318 - val_loss: 0.0173
# Epoch 15/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0232 - val_loss: 0.0128
# Epoch 16/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0358 - val_loss: 0.0148
# Epoch 17/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0351 - val_loss: 0.0139
# Epoch 18/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0325 - val_loss: 0.0123
# Epoch 19/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0245 - val_loss: 0.0155
# Epoch 20/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0383 - val_loss: 0.0120
# Epoch 21/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0193 - val_loss: 0.0168
# Epoch 22/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0442 - val_loss: 0.0118
# Epoch 23/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0257 - val_loss: 0.0187
# Epoch 24/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0363 - val_loss: 0.0137
# Epoch 25/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0411 - val_loss: 0.0151
# Epoch 26/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0236 - val_loss: 0.0187
# Epoch 27/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0307 - val_loss: 0.0140
# Epoch 28/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0252 - val_loss: 0.0140
# Epoch 29/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0368 - val_loss: 0.0139
# Epoch 30/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0380 - val_loss: 0.0158
# Epoch 31/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0390 - val_loss: 0.0258
# Epoch 32/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0376 - val_loss: 0.0122
# Epoch 33/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0420 - val_loss: 0.0139
# Epoch 34/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0402 - val_loss: 0.0129
# Epoch 35/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0234 - val_loss: 0.0132
# Epoch 36/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0338 - val_loss: 0.0150
# Epoch 37/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0393 - val_loss: 0.0119
# Epoch 38/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0428 - val_loss: 0.0142
# Epoch 39/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0274 - val_loss: 0.0118
# Epoch 40/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0418 - val_loss: 0.0117
# Epoch 41/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0250 - val_loss: 0.0162
# Epoch 42/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0388 - val_loss: 0.0152
# Epoch 43/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0323 - val_loss: 0.0119
# Epoch 44/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0222 - val_loss: 0.0124
# Epoch 45/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0336 - val_loss: 0.0115
# Epoch 46/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0309 - val_loss: 0.0114
# Epoch 47/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0382 - val_loss: 0.0126
# Epoch 48/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0270 - val_loss: 0.0126
# Epoch 49/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0282 - val_loss: 0.0142
# Epoch 50/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0406 - val_loss: 0.0113
# Epoch 51/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0369 - val_loss: 0.0114
# Epoch 52/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0346 - val_loss: 0.0134
# Epoch 53/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0342 - val_loss: 0.0125
# Epoch 54/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0324 - val_loss: 0.0130
# Epoch 55/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0262 - val_loss: 0.0110
# Epoch 56/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0463 - val_loss: 0.0134
# Epoch 57/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0252 - val_loss: 0.0112
# Epoch 58/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0218 - val_loss: 0.0114
# Epoch 59/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0275 - val_loss: 0.0204
# Epoch 60/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0319 - val_loss: 0.0139
# Epoch 61/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0333 - val_loss: 0.0150
# Epoch 62/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0272 - val_loss: 0.0152
# Epoch 63/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0324 - val_loss: 0.0221
# Epoch 64/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0232 - val_loss: 0.0124
# Epoch 65/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0290 - val_loss: 0.0125
# Epoch 66/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0290 - val_loss: 0.0154
# Epoch 67/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0225 - val_loss: 0.0146
# Epoch 68/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0243 - val_loss: 0.0124
# Epoch 69/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0293 - val_loss: 0.0133
# Epoch 70/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0353 - val_loss: 0.0109
# Epoch 71/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0291 - val_loss: 0.0135
# Epoch 72/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0224 - val_loss: 0.0118
# Epoch 73/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0343 - val_loss: 0.0126
# Epoch 74/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0240 - val_loss: 0.0134
# Epoch 75/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0226 - val_loss: 0.0128
# Epoch 76/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0371 - val_loss: 0.0189
# Epoch 77/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0202 - val_loss: 0.0129
# Epoch 78/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0279 - val_loss: 0.0195
# Epoch 79/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0227 - val_loss: 0.0152
# Epoch 80/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0240 - val_loss: 0.0120
# Epoch 81/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0281 - val_loss: 0.0132
# Epoch 82/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0256 - val_loss: 0.0140
# Epoch 83/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0264 - val_loss: 0.0134
# Epoch 84/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0319 - val_loss: 0.0134
# Epoch 85/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0423 - val_loss: 0.0133
# Epoch 86/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0148 - val_loss: 0.0123
# Epoch 87/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0272 - val_loss: 0.0130
# Epoch 88/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0243 - val_loss: 0.0123
# Epoch 89/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0295 - val_loss: 0.0122
# Epoch 90/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0351 - val_loss: 0.0160
# Epoch 91/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0297 - val_loss: 0.0213
# Epoch 92/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0264 - val_loss: 0.0130
# Epoch 93/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0222 - val_loss: 0.0143
# Epoch 94/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0250 - val_loss: 0.0115
# Epoch 95/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0381 - val_loss: 0.0106
# Epoch 96/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0301 - val_loss: 0.0119
# Epoch 97/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0336 - val_loss: 0.0179
# Epoch 98/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0362 - val_loss: 0.0252
# Epoch 99/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0293 - val_loss: 0.0105
# Epoch 100/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0233 - val_loss: 0.0122
# Epoch 101/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0343 - val_loss: 0.0108
# Epoch 102/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0265 - val_loss: 0.0149
# Epoch 103/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0237 - val_loss: 0.0113
# Epoch 104/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0206 - val_loss: 0.0137
# Epoch 105/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0376 - val_loss: 0.0112
# Epoch 106/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0204 - val_loss: 0.0119
# Epoch 107/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0252 - val_loss: 0.0132
# Epoch 108/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0288 - val_loss: 0.0116
# Epoch 109/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0314 - val_loss: 0.0122
# Epoch 110/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0226 - val_loss: 0.0222
# Epoch 111/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0433 - val_loss: 0.0135
# Epoch 112/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0221 - val_loss: 0.0212
# Epoch 113/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0359 - val_loss: 0.0096
# Epoch 114/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0281 - val_loss: 0.0084
# Epoch 115/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0260 - val_loss: 0.0091
# Epoch 116/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0183 - val_loss: 0.0117
# Epoch 117/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0199 - val_loss: 0.0152
# Epoch 118/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0217 - val_loss: 0.0115
# Epoch 119/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0167 - val_loss: 0.0204
# Epoch 120/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0175 - val_loss: 0.0112
# Epoch 121/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0129 - val_loss: 0.0095
# Epoch 122/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0144 - val_loss: 0.0094
# Epoch 123/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0214 - val_loss: 0.0106
# Epoch 124/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0163 - val_loss: 0.0278
# Epoch 125/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0165 - val_loss: 0.0140
# Epoch 126/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0196 - val_loss: 0.0079
# Epoch 127/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0245 - val_loss: 0.0089
# Epoch 128/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0130 - val_loss: 0.0102
# Epoch 129/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0170 - val_loss: 0.0118
# Epoch 130/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0212 - val_loss: 0.0154
# Epoch 131/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0198 - val_loss: 0.0095
# Epoch 132/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0131 - val_loss: 0.0069
# Epoch 133/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0146 - val_loss: 0.0083
# Epoch 134/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0125 - val_loss: 0.0090
# Epoch 135/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0165 - val_loss: 0.0117
# Epoch 136/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0163 - val_loss: 0.0116
# Epoch 137/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0176 - val_loss: 0.0077
# Epoch 138/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0138 - val_loss: 0.0066
# Epoch 139/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0192 - val_loss: 0.0069
# Epoch 140/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0112 - val_loss: 0.0127
# Epoch 141/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0227 - val_loss: 0.0136
# Epoch 142/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0185 - val_loss: 0.0093
# Epoch 143/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0151 - val_loss: 0.0075
# Epoch 144/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0186 - val_loss: 0.0091
# Epoch 145/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0106 - val_loss: 0.0085
# Epoch 146/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0173 - val_loss: 0.0088
# Epoch 147/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0219 - val_loss: 0.0085
# Epoch 148/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0177 - val_loss: 0.0080
# Epoch 149/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0161 - val_loss: 0.0074
# Epoch 150/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0181 - val_loss: 0.0107
# Epoch 151/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0137 - val_loss: 0.0059
# Epoch 152/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0182 - val_loss: 0.0088
# Epoch 153/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0139 - val_loss: 0.0078
# Epoch 154/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0126 - val_loss: 0.0132
# Epoch 155/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0178 - val_loss: 0.0126
# Epoch 156/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0120 - val_loss: 0.0107
# Epoch 157/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0199 - val_loss: 0.0088
# Epoch 158/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0139 - val_loss: 0.0077
# Epoch 159/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0130 - val_loss: 0.0092
# Epoch 160/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0147 - val_loss: 0.0069
# Epoch 161/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0142 - val_loss: 0.0078
# Epoch 162/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0102 - val_loss: 0.0080
# Epoch 163/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0112 - val_loss: 0.0089
# Epoch 164/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0125 - val_loss: 0.0090
# Epoch 165/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0142 - val_loss: 0.0077
# Epoch 166/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0148 - val_loss: 0.0095
# Epoch 167/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0155 - val_loss: 0.0095
# Epoch 168/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0150 - val_loss: 0.0069
# Epoch 169/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0171 - val_loss: 0.0125
# Epoch 170/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0097 - val_loss: 0.0090
# Epoch 171/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0139 - val_loss: 0.0082
# Epoch 172/180
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0151 - val_loss: 0.0079
# Epoch 173/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0096 - val_loss: 0.0109
# Epoch 174/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0172 - val_loss: 0.0093
# Epoch 175/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0096 - val_loss: 0.0096
# Epoch 176/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0127 - val_loss: 0.0085
# Epoch 177/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0169 - val_loss: 0.0069
# Epoch 178/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0174 - val_loss: 0.0074
# Epoch 179/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0120 - val_loss: 0.0093
# Epoch 180/180
# 28/28 [==============================] - 0s 3ms/step - loss: 0.0119 - val_loss: 0.0104

# %%
forecasts = LSTM1.predict(x_val)
# inverse transform
y_val_original = inverse_transform(data,y_val,scaler,x_val)
y_predicted = inverse_transform(data,forecasts,scaler,x_val)
evaluate_forecasts(y_val_original, y_predicted, 6, 3)
# Out:
# t+1 RMSE: 13469.292483
# t+1 MAPE: 0.3546
# t+2 RMSE: 25142.396385
# t+2 MAPE: 0.7346
# t+3 RMSE: 27527.751234
# t+3 MAPE: 0.6779

# %%
plot_forecasts(data,train_df,val_df,y_predicted,3)

# %% [markdown]
# # Weekly forecast

# %%
# Check for top 10 products
df.groupby('ProductName_ID').sum()['Quantity'].sort_values(ascending = False)[:10]
# Out:
# ProductName_ID
# 1277    3170543.0
# 2609    3070767.0
# 481     2983412.0
# 993     2837871.0
# 1147    2801077.0
# 1234    2528432.0
# 2802    2521720.0
# 847     2447311.0
# 226     2437948.0
# 1422    2414555.0
# Name: Quantity, dtype: float32

# %%
data = preprocessing(df,product_id='2609',period="Week")
# Out:
# weekly timeseries generated

# %%
plot_series(data.iloc[-106:])

# %%
invalid_index = data.loc['201945':].index
data.drop(index = invalid_index,inplace = True)

# %%
n = data.shape[0]
train_df = data[0:int(n*.8)]
val_df = data[int(n*0.8):]

# %%
plot_acf(data)
plt.show()

# %%
plot_pacf(data, lags=25)
plt.show()

# %%
data
# Out:
#             Quantity
# TimeSeries
# 201601       13109.0
# 201602       13875.0
# 201603       13002.0
# 201604       12562.0
# 201605       12825.0
# ...              ...
# 201940       18399.0
# 201941       20819.0
# 201942       18616.0
# 201943       18152.0
# 201944       13234.0
#
# [200 rows x 1 columns]

# %%
dataset = difference(data)

# %%
n = dataset.shape[0]
train_df = dataset[0:int(n*.8)]
val_df = dataset[int(n*0.8):]
line_plot2(line1 = train_df, line2 = val_df, label1='training',label2='val',title='')

# %%
x_train, y_train, x_val, y_val, scaled_df, scaler = generate_input(dataset,window = 6, out = 3)

# %%
print(scaled_df.shape)
print(x_train.shape)
print(y_train.shape)
print(x_val.shape)
print(y_val.shape)
# Out:
# (199, 1)
# (151, 6, 1)
# (151, 3)
# (38, 6, 1)
# (38, 3)

# %%
LSTM1 = model_base_build(input_shape= (x_train.shape[1],x_train.shape[2]),output_len=y_train.shape[1])
history1 = LSTM1.fit(x_train, y_train, batch_size=4, epochs=100   ,validation_data=(x_val,y_val))
# Out:
# Epoch 1/100
# 38/38 [==============================] - 5s 27ms/step - loss: 0.1049 - val_loss: 0.0208
# Epoch 2/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0168 - val_loss: 0.0189
# Epoch 3/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0167 - val_loss: 0.0187
# Epoch 4/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0173 - val_loss: 0.0190
# Epoch 5/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0158 - val_loss: 0.0184
# Epoch 6/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0139 - val_loss: 0.0187
# Epoch 7/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0173 - val_loss: 0.0189
# Epoch 8/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0135 - val_loss: 0.0183
# Epoch 9/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0141 - val_loss: 0.0183
# Epoch 10/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0126 - val_loss: 0.0178
# Epoch 11/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0159 - val_loss: 0.0185
# Epoch 12/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0138 - val_loss: 0.0181
# Epoch 13/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0149 - val_loss: 0.0186
# Epoch 14/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0183 - val_loss: 0.0175
# Epoch 15/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0162 - val_loss: 0.0181
# Epoch 16/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0145 - val_loss: 0.0176
# Epoch 17/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0132 - val_loss: 0.0172
# Epoch 18/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0152 - val_loss: 0.0170
# Epoch 19/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0149 - val_loss: 0.0171
# Epoch 20/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0142 - val_loss: 0.0167
# Epoch 21/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0146 - val_loss: 0.0162
# Epoch 22/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0147 - val_loss: 0.0158
# Epoch 23/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0129 - val_loss: 0.0156
# Epoch 24/100
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0130 - val_loss: 0.0170
# Epoch 25/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0126 - val_loss: 0.0163
# Epoch 26/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0111 - val_loss: 0.0163
# Epoch 27/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0130 - val_loss: 0.0158
# Epoch 28/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0119 - val_loss: 0.0164
# Epoch 29/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0124 - val_loss: 0.0167
# Epoch 30/100
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0133 - val_loss: 0.0169
# Epoch 31/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0113 - val_loss: 0.0164
# Epoch 32/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0114 - val_loss: 0.0159
# Epoch 33/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0104 - val_loss: 0.0168
# Epoch 34/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0112 - val_loss: 0.0161
# Epoch 35/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0127 - val_loss: 0.0160
# Epoch 36/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0109 - val_loss: 0.0165
# Epoch 37/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0114 - val_loss: 0.0165
# Epoch 38/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0104 - val_loss: 0.0162
# Epoch 39/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0096 - val_loss: 0.0169
# Epoch 40/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0108 - val_loss: 0.0161
# Epoch 41/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0133 - val_loss: 0.0160
# Epoch 42/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0123 - val_loss: 0.0157
# Epoch 43/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0115 - val_loss: 0.0154
# Epoch 44/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0115 - val_loss: 0.0159
# Epoch 45/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0111 - val_loss: 0.0160
# Epoch 46/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0114 - val_loss: 0.0162
# Epoch 47/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0102 - val_loss: 0.0162
# Epoch 48/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0093 - val_loss: 0.0160
# Epoch 49/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0110 - val_loss: 0.0159
# Epoch 50/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0104 - val_loss: 0.0156
# Epoch 51/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0128 - val_loss: 0.0157
# Epoch 52/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0098 - val_loss: 0.0160
# Epoch 53/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0117 - val_loss: 0.0156
# Epoch 54/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0118 - val_loss: 0.0154
# Epoch 55/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0087 - val_loss: 0.0153
# Epoch 56/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0116 - val_loss: 0.0163
# Epoch 57/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0109 - val_loss: 0.0162
# Epoch 58/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0113 - val_loss: 0.0149
# Epoch 59/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0118 - val_loss: 0.0152
# Epoch 60/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0093 - val_loss: 0.0155
# Epoch 61/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0093 - val_loss: 0.0155
# Epoch 62/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0100 - val_loss: 0.0153
# Epoch 63/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0102 - val_loss: 0.0152
# Epoch 64/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0117 - val_loss: 0.0152
# Epoch 65/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0099 - val_loss: 0.0159
# Epoch 66/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0095 - val_loss: 0.0148
# Epoch 67/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0126 - val_loss: 0.0151
# Epoch 68/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0115 - val_loss: 0.0156
# Epoch 69/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0123 - val_loss: 0.0149
# Epoch 70/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0107 - val_loss: 0.0147
# Epoch 71/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0104 - val_loss: 0.0148
# Epoch 72/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0099 - val_loss: 0.0147
# Epoch 73/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0098 - val_loss: 0.0145
# Epoch 74/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0130 - val_loss: 0.0141
# Epoch 75/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0110 - val_loss: 0.0142
# Epoch 76/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0123 - val_loss: 0.0147
# Epoch 77/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0105 - val_loss: 0.0142
# Epoch 78/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0099 - val_loss: 0.0156
# Epoch 79/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0107 - val_loss: 0.0142
# Epoch 80/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0110 - val_loss: 0.0144
# Epoch 81/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0095 - val_loss: 0.0140
# Epoch 82/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0102 - val_loss: 0.0141
# Epoch 83/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0081 - val_loss: 0.0147
# Epoch 84/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0100 - val_loss: 0.0148
# Epoch 85/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0107 - val_loss: 0.0146
# Epoch 86/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0097 - val_loss: 0.0142
# Epoch 87/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0099 - val_loss: 0.0143
# Epoch 88/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0095 - val_loss: 0.0141
# Epoch 89/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0096 - val_loss: 0.0143
# Epoch 90/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0104 - val_loss: 0.0142
# Epoch 91/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0110 - val_loss: 0.0141
# Epoch 92/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0088 - val_loss: 0.0145
# Epoch 93/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0101 - val_loss: 0.0145
# Epoch 94/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0109 - val_loss: 0.0141
# Epoch 95/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0079 - val_loss: 0.0138
# Epoch 96/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0095 - val_loss: 0.0148
# Epoch 97/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0094 - val_loss: 0.0144
# Epoch 98/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0093 - val_loss: 0.0147
# Epoch 99/100
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0076 - val_loss: 0.0139
# Epoch 100/100
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0089 - val_loss: 0.0144

# %%
histories = [history1]
names = ['LSTM1']
plot_loss_histories(histories,names)

# %%
forecasts = LSTM1.predict(x_val)
#evaluate_forecasts(y_val, forecasts, 6, 3)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001AC88AEC8B0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
y_val_original = inverse_transform(data, y_val, scaler,x_val)
y_predicted = inverse_transform(data,forecasts,scaler,x_val)
evaluate_forecasts(y_val_original, y_predicted, 6, 3)
# Out:
# t+1 RMSE: 1518.066451
# t+1 MAPE: 0.0676
# t+2 RMSE: 1607.001945
# t+2 MAPE: 0.0758
# t+3 RMSE: 1703.570882
# t+3 MAPE: 0.0763

# %%
plot_forecasts(data,train_df,val_df,y_predicted,3)

# %% [markdown]
# ## 1 week ahead

# %%
x_train, y_train, x_val, y_val, scaled_df, scaler = generate_input(dataset,window = 4, out = 1)
LSTM1 = model_base_build(input_shape= (x_train.shape[1],x_train.shape[2]),output_len=y_train.shape[1])
history1 = LSTM1.fit(x_train, y_train, batch_size=2, epochs=100   ,validation_data=(x_val,y_val))
histories = [history1]
names = ['LSTM1']
plot_loss_histories(histories,names)
# Out:
# Epoch 1/100
# 78/78 [==============================] - 5s 14ms/step - loss: 0.0387 - val_loss: 0.0200
# Epoch 2/100
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0142 - val_loss: 0.0221
# Epoch 3/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0148 - val_loss: 0.0204
# Epoch 4/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0198 - val_loss: 0.0199
# Epoch 5/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0190 - val_loss: 0.0193
# Epoch 6/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0177 - val_loss: 0.0186
# Epoch 7/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0170 - val_loss: 0.0227
# Epoch 8/100
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0120 - val_loss: 0.0176
# Epoch 9/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0136 - val_loss: 0.0223
# Epoch 10/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0201 - val_loss: 0.0169
# Epoch 11/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0125 - val_loss: 0.0159
# Epoch 12/100
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0108 - val_loss: 0.0153
# Epoch 13/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0136 - val_loss: 0.0155
# Epoch 14/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0114 - val_loss: 0.0242
# Epoch 15/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0134 - val_loss: 0.0147
# Epoch 16/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0137 - val_loss: 0.0150
# Epoch 17/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0098 - val_loss: 0.0191
# Epoch 18/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0122 - val_loss: 0.0147
# Epoch 19/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0120 - val_loss: 0.0162
# Epoch 20/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0117 - val_loss: 0.0148
# Epoch 21/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0102 - val_loss: 0.0161
# Epoch 22/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0110 - val_loss: 0.0146
# Epoch 23/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0098 - val_loss: 0.0154
# Epoch 24/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0104 - val_loss: 0.0159
# Epoch 25/100
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0087 - val_loss: 0.0195
# Epoch 26/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0096 - val_loss: 0.0165
# Epoch 27/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0077 - val_loss: 0.0153
# Epoch 28/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0086 - val_loss: 0.0158
# Epoch 29/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0084 - val_loss: 0.0157
# Epoch 30/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0097 - val_loss: 0.0154
# Epoch 31/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0077 - val_loss: 0.0165
# Epoch 32/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0089 - val_loss: 0.0174
# Epoch 33/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0076 - val_loss: 0.0164
# Epoch 34/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0082 - val_loss: 0.0170
# Epoch 35/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0070 - val_loss: 0.0216
# Epoch 36/100
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0105 - val_loss: 0.0149
# Epoch 37/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0072 - val_loss: 0.0153
# Epoch 38/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0084 - val_loss: 0.0154
# Epoch 39/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 0.0179
# Epoch 40/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0105 - val_loss: 0.0184
# Epoch 41/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0093 - val_loss: 0.0171
# Epoch 42/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0079 - val_loss: 0.0192
# Epoch 43/100
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0090 - val_loss: 0.0187
# Epoch 44/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0097 - val_loss: 0.0168
# Epoch 45/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0089 - val_loss: 0.0163
# Epoch 46/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0086 - val_loss: 0.0196
# Epoch 47/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0082 - val_loss: 0.0199
# Epoch 48/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0082 - val_loss: 0.0179
# Epoch 49/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0077 - val_loss: 0.0198
# Epoch 50/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0092 - val_loss: 0.0173
# Epoch 51/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0091 - val_loss: 0.0171
# Epoch 52/100
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0078 - val_loss: 0.0186
# Epoch 53/100
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0096 - val_loss: 0.0176
# Epoch 54/100
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0083 - val_loss: 0.0185
# Epoch 55/100
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0069 - val_loss: 0.0184
# Epoch 56/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0089 - val_loss: 0.0188
# Epoch 57/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0094 - val_loss: 0.0185
# Epoch 58/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 0.0168
# Epoch 59/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 0.0203
# Epoch 60/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0073 - val_loss: 0.0177
# Epoch 61/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0106 - val_loss: 0.0181
# Epoch 62/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0083 - val_loss: 0.0194
# Epoch 63/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0093 - val_loss: 0.0205
# Epoch 64/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0088 - val_loss: 0.0187
# Epoch 65/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0070 - val_loss: 0.0189
# Epoch 66/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0070 - val_loss: 0.0193
# Epoch 67/100
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0084 - val_loss: 0.0225
# Epoch 68/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0087 - val_loss: 0.0195
# Epoch 69/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0083 - val_loss: 0.0188
# Epoch 70/100
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0085 - val_loss: 0.0236
# Epoch 71/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0081 - val_loss: 0.0182
# Epoch 72/100
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0080 - val_loss: 0.0223
# Epoch 73/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0090 - val_loss: 0.0285
# Epoch 74/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0104 - val_loss: 0.0183
# Epoch 75/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 0.0191
# Epoch 76/100
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0102 - val_loss: 0.0211
# Epoch 77/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 0.0205
# Epoch 78/100
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0086 - val_loss: 0.0175
# Epoch 79/100
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0083 - val_loss: 0.0177
# Epoch 80/100
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0072 - val_loss: 0.0233
# Epoch 81/100
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0085 - val_loss: 0.0208
# Epoch 82/100
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0069 - val_loss: 0.0190
# Epoch 83/100
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0079 - val_loss: 0.0214
# Epoch 84/100
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0075 - val_loss: 0.0176
# Epoch 85/100
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0083 - val_loss: 0.0210
# Epoch 86/100
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0069 - val_loss: 0.0182
# Epoch 87/100
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0071 - val_loss: 0.0181
# Epoch 88/100
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0103 - val_loss: 0.0210
# Epoch 89/100
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0063 - val_loss: 0.0192
# Epoch 90/100
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0068 - val_loss: 0.0250
# Epoch 91/100
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0074 - val_loss: 0.0207
# Epoch 92/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0076 - val_loss: 0.0208
# Epoch 93/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0170
# Epoch 94/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0111 - val_loss: 0.0227
# Epoch 95/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0085 - val_loss: 0.0184
# Epoch 96/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0067 - val_loss: 0.0230
# Epoch 97/100
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0079 - val_loss: 0.0181
# Epoch 98/100
# 78/78 [==============================] - 0s 4ms/step - loss: 0.0074 - val_loss: 0.0220
# Epoch 99/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0075 - val_loss: 0.0191
# Epoch 100/100
# 78/78 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 0.0184

# %%
forecasts = LSTM1.predict(x_val)
evaluate_forecasts(y_val, forecasts, 4, 1)
# Out:
# t+1 RMSE: 0.135585

# %%
y_val_original = inverse_transform(data, y_val, scaler,x_val)
y_predicted = inverse_transform(data,forecasts,scaler,x_val)
evaluate_forecasts(y_val_original, y_predicted, 4, 1)
# Out:
# t+1 RMSE: 1841.376659
# t+1 MAPE: 0.07

# %%
lines = plot_forecasts(data,train_df,val_df,y_predicted,1)
